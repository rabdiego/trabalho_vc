# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import optuna

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay, precision_score, recall_score, f1_score

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC

# %%
df = pd.read_csv('../data/data.csv')
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, shuffle=True, random_state=0
)

# %%
scaler = StandardScaler()

X_train_original = X_train
X_test_original = X_test

X_train = X_train[['contrast_score', 'sharpness_score', 'noise_score']]
X_test = X_test[['contrast_score', 'sharpness_score', 'noise_score']]

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
def objective(trial):
    classifier_name = trial.suggest_categorical("classifier", [
        "LogisticRegression", "KNN", "DecisionTree", "RandomForest", "MLP", "SVC"
    ])

    if classifier_name == "LogisticRegression":
        C = trial.suggest_loguniform("lr_C", 1e-4, 1e2)
        model = LogisticRegression(C=C, max_iter=1000)

    elif classifier_name == "KNN":
        n_neighbors = trial.suggest_int("knn_n_neighbors", 1, 30)
        model = KNeighborsClassifier(n_neighbors=n_neighbors)

    elif classifier_name == "DecisionTree":
        max_depth = trial.suggest_int("dt_max_depth", 1, 20)
        model = DecisionTreeClassifier(max_depth=max_depth)

    elif classifier_name == "RandomForest":
        n_estimators = trial.suggest_int("rf_n_estimators", 10, 200)
        max_depth = trial.suggest_int("rf_max_depth", 2, 20)
        model = RandomForestClassifier(n_estimators=n_estimators, max_depth=max_depth)

    elif classifier_name == "MLP":
        hidden_layer_sizes = trial.suggest_categorical("mlp_hidden_layer_sizes", [(50,), (100,), (50, 50)])
        alpha = trial.suggest_loguniform("mlp_alpha", 1e-5, 1e-1)
        model = MLPClassifier(hidden_layer_sizes=hidden_layer_sizes, alpha=alpha, max_iter=1000)

    elif classifier_name == "SVC":
        C = trial.suggest_loguniform("svc_C", 1e-2, 1e2)
        gamma = trial.suggest_loguniform("svc_gamma", 1e-4, 1e-1)
        model = SVC(C=C, gamma=gamma)

    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    acc = accuracy_score(y_test, y_pred)
    return acc

# %%
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=50)
# Out:
# [I 2025-07-28 18:19:16,851] A new study created in memory with name: no-name-20f1d354-5695-4615-8a91-8f3fb6118836
# /tmp/ipykernel_1176/229894683.py:29: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("svc_C", 1e-2, 1e2)
# /tmp/ipykernel_1176/229894683.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform("svc_gamma", 1e-4, 1e-1)
# [I 2025-07-28 18:19:16,949] Trial 0 finished with value: 0.490625 and parameters: {'classifier': 'SVC', 'svc_C': 0.1359492885699183, 'svc_gamma': 0.00047030382639870304}. Best is trial 0 with value: 0.490625.
# /tmp/ipykernel_1176/229894683.py:29: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("svc_C", 1e-2, 1e2)
# /tmp/ipykernel_1176/229894683.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform("svc_gamma", 1e-4, 1e-1)
# [I 2025-07-28 18:19:17,032] Trial 1 finished with value: 0.490625 and parameters: {'classifier': 'SVC', 'svc_C': 0.019613425244359765, 'svc_gamma': 0.0005367127616290714}. Best is trial 0 with value: 0.490625.
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (50,) which is of type tuple.
#   warnings.warn(message)
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (100,) which is of type tuple.
#   warnings.warn(message)
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (50, 50) which is of type tuple.
#   warnings.warn(message)
# /tmp/ipykernel_1176/229894683.py:25: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform("mlp_alpha", 1e-5, 1e-1)
# [I 2025-07-28 18:19:19,691] Trial 2 finished with value: 0.93125 and parameters: {'classifier': 'MLP', 'mlp_hidden_layer_sizes': (50, 50), 'mlp_alpha': 2.8587855262743184e-05}. Best is trial 2 with value: 0.93125.
# [I 2025-07-28 18:19:19,713] Trial 3 finished with value: 0.878125 and parameters: {'classifier': 'DecisionTree', 'dt_max_depth': 15}. Best is trial 2 with value: 0.93125.
# /tmp/ipykernel_1176/229894683.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("lr_C", 1e-4, 1e2)
# [I 2025-07-28 18:19:19,725] Trial 4 finished with value: 0.75625 and parameters: {'classifier': 'LogisticRegression', 'lr_C': 2.4520456804713207}. Best is trial 2 with value: 0.93125.
# [I 2025-07-28 18:19:19,744] Trial 5 finished with value: 0.878125 and parameters: {'classifier': 'DecisionTree', 'dt_max_depth': 19}. Best is trial 2 with value: 0.93125.
# /tmp/ipykernel_1176/229894683.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("lr_C", 1e-4, 1e2)
# [I 2025-07-28 18:19:19,765] Trial 6 finished with value: 0.7375 and parameters: {'classifier': 'LogisticRegression', 'lr_C': 0.025796808764327602}. Best is trial 2 with value: 0.93125.
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (50,) which is of type tuple.
#   warnings.warn(message)
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (100,) which is of type tuple.
#   warnings.warn(message)
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (50, 50) which is of type tuple.
#   warnings.warn(message)
# /tmp/ipykernel_1176/229894683.py:25: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform("mlp_alpha", 1e-5, 1e-1)
# [I 2025-07-28 18:19:21,713] Trial 7 finished with value: 0.93125 and parameters: {'classifier': 'MLP', 'mlp_hidden_layer_sizes': (50,), 'mlp_alpha': 0.0021888664397508736}. Best is trial 2 with value: 0.93125.
# [I 2025-07-28 18:19:21,738] Trial 8 finished with value: 0.921875 and parameters: {'classifier': 'KNN', 'knn_n_neighbors': 21}. Best is trial 2 with value: 0.93125.
# /tmp/ipykernel_1176/229894683.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("lr_C", 1e-4, 1e2)
# [I 2025-07-28 18:19:21,744] Trial 9 finished with value: 0.75625 and parameters: {'classifier': 'LogisticRegression', 'lr_C': 33.307884095054625}. Best is trial 2 with value: 0.93125.
# [I 2025-07-28 18:19:22,121] Trial 10 finished with value: 0.909375 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 113, 'rf_max_depth': 20}. Best is trial 2 with value: 0.93125.
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (50,) which is of type tuple.
#   warnings.warn(message)
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (100,) which is of type tuple.
#   warnings.warn(message)
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (50, 50) which is of type tuple.
#   warnings.warn(message)
# /tmp/ipykernel_1176/229894683.py:25: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform("mlp_alpha", 1e-5, 1e-1)
# [I 2025-07-28 18:19:24,598] Trial 11 finished with value: 0.9375 and parameters: {'classifier': 'MLP', 'mlp_hidden_layer_sizes': (50, 50), 'mlp_alpha': 0.0008171418738309747}. Best is trial 11 with value: 0.9375.
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (50,) which is of type tuple.
#   warnings.warn(message)
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (100,) which is of type tuple.
#   warnings.warn(message)
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (50, 50) which is of type tuple.
#   warnings.warn(message)
# /tmp/ipykernel_1176/229894683.py:25: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform("mlp_alpha", 1e-5, 1e-1)
# [I 2025-07-28 18:19:26,406] Trial 12 finished with value: 0.9375 and parameters: {'classifier': 'MLP', 'mlp_hidden_layer_sizes': (50, 50), 'mlp_alpha': 1.0596664216635862e-05}. Best is trial 11 with value: 0.9375.
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (50,) which is of type tuple.
#   warnings.warn(message)
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (100,) which is of type tuple.
#   warnings.warn(message)
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (50, 50) which is of type tuple.
#   warnings.warn(message)
# /tmp/ipykernel_1176/229894683.py:25: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform("mlp_alpha", 1e-5, 1e-1)
# [I 2025-07-28 18:19:28,219] Trial 13 finished with value: 0.934375 and parameters: {'classifier': 'MLP', 'mlp_hidden_layer_sizes': (50, 50), 'mlp_alpha': 1.1118497250612338e-05}. Best is trial 11 with value: 0.9375.
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (50,) which is of type tuple.
#   warnings.warn(message)
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (100,) which is of type tuple.
#   warnings.warn(message)
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (50, 50) which is of type tuple.
#   warnings.warn(message)
# /tmp/ipykernel_1176/229894683.py:25: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform("mlp_alpha", 1e-5, 1e-1)
# [I 2025-07-28 18:19:29,744] Trial 14 finished with value: 0.9375 and parameters: {'classifier': 'MLP', 'mlp_hidden_layer_sizes': (100,), 'mlp_alpha': 0.07207469303161611}. Best is trial 11 with value: 0.9375.
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (50,) which is of type tuple.
#   warnings.warn(message)
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (100,) which is of type tuple.
#   warnings.warn(message)
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (50, 50) which is of type tuple.
#   warnings.warn(message)
# /tmp/ipykernel_1176/229894683.py:25: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform("mlp_alpha", 1e-5, 1e-1)
# [I 2025-07-28 18:19:32,220] Trial 15 finished with value: 0.93125 and parameters: {'classifier': 'MLP', 'mlp_hidden_layer_sizes': (50, 50), 'mlp_alpha': 0.0004055520545881207}. Best is trial 11 with value: 0.9375.
# [I 2025-07-28 18:19:32,282] Trial 16 finished with value: 0.86875 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 14, 'rf_max_depth': 2}. Best is trial 11 with value: 0.9375.
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (50,) which is of type tuple.
#   warnings.warn(message)
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (100,) which is of type tuple.
#   warnings.warn(message)
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (50, 50) which is of type tuple.
#   warnings.warn(message)
# /tmp/ipykernel_1176/229894683.py:25: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform("mlp_alpha", 1e-5, 1e-1)
# [I 2025-07-28 18:19:34,263] Trial 17 finished with value: 0.9375 and parameters: {'classifier': 'MLP', 'mlp_hidden_layer_sizes': (50, 50), 'mlp_alpha': 0.000676783552622991}. Best is trial 11 with value: 0.9375.
# [I 2025-07-28 18:19:34,297] Trial 18 finished with value: 0.93125 and parameters: {'classifier': 'KNN', 'knn_n_neighbors': 3}. Best is trial 11 with value: 0.9375.
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (50,) which is of type tuple.
#   warnings.warn(message)
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (100,) which is of type tuple.
#   warnings.warn(message)
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (50, 50) which is of type tuple.
#   warnings.warn(message)
# /tmp/ipykernel_1176/229894683.py:25: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform("mlp_alpha", 1e-5, 1e-1)
# [I 2025-07-28 18:19:35,935] Trial 19 finished with value: 0.93125 and parameters: {'classifier': 'MLP', 'mlp_hidden_layer_sizes': (50, 50), 'mlp_alpha': 0.009416665663590625}. Best is trial 11 with value: 0.9375.
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (50,) which is of type tuple.
#   warnings.warn(message)
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (100,) which is of type tuple.
#   warnings.warn(message)
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (50, 50) which is of type tuple.
#   warnings.warn(message)
# /tmp/ipykernel_1176/229894683.py:25: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform("mlp_alpha", 1e-5, 1e-1)
# [I 2025-07-28 18:19:37,624] Trial 20 finished with value: 0.934375 and parameters: {'classifier': 'MLP', 'mlp_hidden_layer_sizes': (50,), 'mlp_alpha': 0.00010945451374120981}. Best is trial 11 with value: 0.9375.
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (50,) which is of type tuple.
#   warnings.warn(message)
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (100,) which is of type tuple.
#   warnings.warn(message)
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (50, 50) which is of type tuple.
#   warnings.warn(message)
# /tmp/ipykernel_1176/229894683.py:25: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform("mlp_alpha", 1e-5, 1e-1)
# [I 2025-07-28 18:19:38,927] Trial 21 finished with value: 0.934375 and parameters: {'classifier': 'MLP', 'mlp_hidden_layer_sizes': (100,), 'mlp_alpha': 0.08907934414552819}. Best is trial 11 with value: 0.9375.
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (50,) which is of type tuple.
#   warnings.warn(message)
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (100,) which is of type tuple.
#   warnings.warn(message)
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (50, 50) which is of type tuple.
#   warnings.warn(message)
# /tmp/ipykernel_1176/229894683.py:25: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform("mlp_alpha", 1e-5, 1e-1)
# [I 2025-07-28 18:19:40,286] Trial 22 finished with value: 0.934375 and parameters: {'classifier': 'MLP', 'mlp_hidden_layer_sizes': (100,), 'mlp_alpha': 0.06591566924724142}. Best is trial 11 with value: 0.9375.
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (50,) which is of type tuple.
#   warnings.warn(message)
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (100,) which is of type tuple.
#   warnings.warn(message)
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (50, 50) which is of type tuple.
#   warnings.warn(message)
# /tmp/ipykernel_1176/229894683.py:25: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform("mlp_alpha", 1e-5, 1e-1)
# [I 2025-07-28 18:19:42,270] Trial 23 finished with value: 0.934375 and parameters: {'classifier': 'MLP', 'mlp_hidden_layer_sizes': (100,), 'mlp_alpha': 0.00678173251428526}. Best is trial 11 with value: 0.9375.
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (50,) which is of type tuple.
#   warnings.warn(message)
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (100,) which is of type tuple.
#   warnings.warn(message)
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (50, 50) which is of type tuple.
#   warnings.warn(message)
# /tmp/ipykernel_1176/229894683.py:25: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform("mlp_alpha", 1e-5, 1e-1)
# [I 2025-07-28 18:19:43,694] Trial 24 finished with value: 0.940625 and parameters: {'classifier': 'MLP', 'mlp_hidden_layer_sizes': (100,), 'mlp_alpha': 0.016311032697499686}. Best is trial 24 with value: 0.940625.
# [I 2025-07-28 18:19:43,704] Trial 25 finished with value: 0.709375 and parameters: {'classifier': 'DecisionTree', 'dt_max_depth': 1}. Best is trial 24 with value: 0.940625.
# /tmp/ipykernel_1176/229894683.py:29: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("svc_C", 1e-2, 1e2)
# /tmp/ipykernel_1176/229894683.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform("svc_gamma", 1e-4, 1e-1)
# [I 2025-07-28 18:19:43,747] Trial 26 finished with value: 0.925 and parameters: {'classifier': 'SVC', 'svc_C': 57.08037312495333, 'svc_gamma': 0.09585383792128466}. Best is trial 24 with value: 0.940625.
# [I 2025-07-28 18:19:43,777] Trial 27 finished with value: 0.9125 and parameters: {'classifier': 'KNN', 'knn_n_neighbors': 30}. Best is trial 24 with value: 0.940625.
# [I 2025-07-28 18:19:44,295] Trial 28 finished with value: 0.9125 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 189, 'rf_max_depth': 11}. Best is trial 24 with value: 0.940625.
# /tmp/ipykernel_1176/229894683.py:29: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("svc_C", 1e-2, 1e2)
# /tmp/ipykernel_1176/229894683.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform("svc_gamma", 1e-4, 1e-1)
# [I 2025-07-28 18:19:44,336] Trial 29 finished with value: 0.9125 and parameters: {'classifier': 'SVC', 'svc_C': 16.469216220146173, 'svc_gamma': 0.03149032120952051}. Best is trial 24 with value: 0.940625.
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (50,) which is of type tuple.
#   warnings.warn(message)
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (100,) which is of type tuple.
#   warnings.warn(message)
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (50, 50) which is of type tuple.
#   warnings.warn(message)
# /tmp/ipykernel_1176/229894683.py:25: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform("mlp_alpha", 1e-5, 1e-1)
# [I 2025-07-28 18:19:45,377] Trial 30 finished with value: 0.94375 and parameters: {'classifier': 'MLP', 'mlp_hidden_layer_sizes': (50, 50), 'mlp_alpha': 0.00011741869923165701}. Best is trial 30 with value: 0.94375.
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (50,) which is of type tuple.
#   warnings.warn(message)
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (100,) which is of type tuple.
#   warnings.warn(message)
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (50, 50) which is of type tuple.
#   warnings.warn(message)
# /tmp/ipykernel_1176/229894683.py:25: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform("mlp_alpha", 1e-5, 1e-1)
# [I 2025-07-28 18:19:47,732] Trial 31 finished with value: 0.94375 and parameters: {'classifier': 'MLP', 'mlp_hidden_layer_sizes': (50, 50), 'mlp_alpha': 9.845170880034635e-05}. Best is trial 30 with value: 0.94375.
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (50,) which is of type tuple.
#   warnings.warn(message)
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (100,) which is of type tuple.
#   warnings.warn(message)
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (50, 50) which is of type tuple.
#   warnings.warn(message)
# /tmp/ipykernel_1176/229894683.py:25: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform("mlp_alpha", 1e-5, 1e-1)
# [I 2025-07-28 18:19:49,487] Trial 32 finished with value: 0.934375 and parameters: {'classifier': 'MLP', 'mlp_hidden_layer_sizes': (50, 50), 'mlp_alpha': 0.000200248387946805}. Best is trial 30 with value: 0.94375.
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (50,) which is of type tuple.
#   warnings.warn(message)
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (100,) which is of type tuple.
#   warnings.warn(message)
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (50, 50) which is of type tuple.
#   warnings.warn(message)
# /tmp/ipykernel_1176/229894683.py:25: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform("mlp_alpha", 1e-5, 1e-1)
# [I 2025-07-28 18:19:51,781] Trial 33 finished with value: 0.925 and parameters: {'classifier': 'MLP', 'mlp_hidden_layer_sizes': (50, 50), 'mlp_alpha': 0.00012864989832327646}. Best is trial 30 with value: 0.94375.
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (50,) which is of type tuple.
#   warnings.warn(message)
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (100,) which is of type tuple.
#   warnings.warn(message)
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (50, 50) which is of type tuple.
#   warnings.warn(message)
# /tmp/ipykernel_1176/229894683.py:25: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform("mlp_alpha", 1e-5, 1e-1)
# [I 2025-07-28 18:19:53,577] Trial 34 finished with value: 0.9375 and parameters: {'classifier': 'MLP', 'mlp_hidden_layer_sizes': (50, 50), 'mlp_alpha': 4.701938447816316e-05}. Best is trial 30 with value: 0.94375.
# /tmp/ipykernel_1176/229894683.py:29: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("svc_C", 1e-2, 1e2)
# /tmp/ipykernel_1176/229894683.py:30: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform("svc_gamma", 1e-4, 1e-1)
# [I 2025-07-28 18:19:53,631] Trial 35 finished with value: 0.753125 and parameters: {'classifier': 'SVC', 'svc_C': 1.6862783902493377, 'svc_gamma': 0.006625008062618561}. Best is trial 30 with value: 0.94375.
# [I 2025-07-28 18:19:53,644] Trial 36 finished with value: 0.88125 and parameters: {'classifier': 'DecisionTree', 'dt_max_depth': 5}. Best is trial 30 with value: 0.94375.
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (50,) which is of type tuple.
#   warnings.warn(message)
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (100,) which is of type tuple.
#   warnings.warn(message)
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (50, 50) which is of type tuple.
#   warnings.warn(message)
# /tmp/ipykernel_1176/229894683.py:25: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform("mlp_alpha", 1e-5, 1e-1)
# [I 2025-07-28 18:19:55,518] Trial 37 finished with value: 0.940625 and parameters: {'classifier': 'MLP', 'mlp_hidden_layer_sizes': (100,), 'mlp_alpha': 0.0015443739865221627}. Best is trial 30 with value: 0.94375.
# /tmp/ipykernel_1176/229894683.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("lr_C", 1e-4, 1e2)
# [I 2025-07-28 18:19:55,529] Trial 38 finished with value: 0.73125 and parameters: {'classifier': 'LogisticRegression', 'lr_C': 0.0001664747205927298}. Best is trial 30 with value: 0.94375.
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (50,) which is of type tuple.
#   warnings.warn(message)
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (100,) which is of type tuple.
#   warnings.warn(message)
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (50, 50) which is of type tuple.
#   warnings.warn(message)
# /tmp/ipykernel_1176/229894683.py:25: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform("mlp_alpha", 1e-5, 1e-1)
# [I 2025-07-28 18:19:57,150] Trial 39 finished with value: 0.9375 and parameters: {'classifier': 'MLP', 'mlp_hidden_layer_sizes': (100,), 'mlp_alpha': 0.0028030592502532596}. Best is trial 30 with value: 0.94375.
# [I 2025-07-28 18:19:57,176] Trial 40 finished with value: 0.9 and parameters: {'classifier': 'KNN', 'knn_n_neighbors': 1}. Best is trial 30 with value: 0.94375.
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (50,) which is of type tuple.
#   warnings.warn(message)
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (100,) which is of type tuple.
#   warnings.warn(message)
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (50, 50) which is of type tuple.
#   warnings.warn(message)
# /tmp/ipykernel_1176/229894683.py:25: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform("mlp_alpha", 1e-5, 1e-1)
# [I 2025-07-28 18:19:58,941] Trial 41 finished with value: 0.934375 and parameters: {'classifier': 'MLP', 'mlp_hidden_layer_sizes': (100,), 'mlp_alpha': 0.014386338229067258}. Best is trial 30 with value: 0.94375.
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (50,) which is of type tuple.
#   warnings.warn(message)
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (100,) which is of type tuple.
#   warnings.warn(message)
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (50, 50) which is of type tuple.
#   warnings.warn(message)
# /tmp/ipykernel_1176/229894683.py:25: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform("mlp_alpha", 1e-5, 1e-1)
# [I 2025-07-28 18:20:00,445] Trial 42 finished with value: 0.9375 and parameters: {'classifier': 'MLP', 'mlp_hidden_layer_sizes': (100,), 'mlp_alpha': 0.0014540743286871169}. Best is trial 30 with value: 0.94375.
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (50,) which is of type tuple.
#   warnings.warn(message)
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (100,) which is of type tuple.
#   warnings.warn(message)
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (50, 50) which is of type tuple.
#   warnings.warn(message)
# /tmp/ipykernel_1176/229894683.py:25: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform("mlp_alpha", 1e-5, 1e-1)
# [I 2025-07-28 18:20:02,209] Trial 43 finished with value: 0.940625 and parameters: {'classifier': 'MLP', 'mlp_hidden_layer_sizes': (50, 50), 'mlp_alpha': 0.0003468144274511485}. Best is trial 30 with value: 0.94375.
# /tmp/ipykernel_1176/229894683.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("lr_C", 1e-4, 1e2)
# [I 2025-07-28 18:20:02,220] Trial 44 finished with value: 0.71875 and parameters: {'classifier': 'LogisticRegression', 'lr_C': 0.00013114738984524273}. Best is trial 30 with value: 0.94375.
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (50,) which is of type tuple.
#   warnings.warn(message)
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (100,) which is of type tuple.
#   warnings.warn(message)
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (50, 50) which is of type tuple.
#   warnings.warn(message)
# /tmp/ipykernel_1176/229894683.py:25: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform("mlp_alpha", 1e-5, 1e-1)
# [I 2025-07-28 18:20:04,194] Trial 45 finished with value: 0.9375 and parameters: {'classifier': 'MLP', 'mlp_hidden_layer_sizes': (50,), 'mlp_alpha': 0.0002772972775363448}. Best is trial 30 with value: 0.94375.
# [I 2025-07-28 18:20:04,222] Trial 46 finished with value: 0.8875 and parameters: {'classifier': 'DecisionTree', 'dt_max_depth': 10}. Best is trial 30 with value: 0.94375.
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (50,) which is of type tuple.
#   warnings.warn(message)
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (100,) which is of type tuple.
#   warnings.warn(message)
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (50, 50) which is of type tuple.
#   warnings.warn(message)
# /tmp/ipykernel_1176/229894683.py:25: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform("mlp_alpha", 1e-5, 1e-1)
# [I 2025-07-28 18:20:06,040] Trial 47 finished with value: 0.934375 and parameters: {'classifier': 'MLP', 'mlp_hidden_layer_sizes': (100,), 'mlp_alpha': 5.560242067285248e-05}. Best is trial 30 with value: 0.94375.
# [I 2025-07-28 18:20:06,076] Trial 48 finished with value: 0.8625 and parameters: {'classifier': 'RandomForest', 'rf_n_estimators': 12, 'rf_max_depth': 2}. Best is trial 30 with value: 0.94375.
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (50,) which is of type tuple.
#   warnings.warn(message)
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (100,) which is of type tuple.
#   warnings.warn(message)
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/optuna/distributions.py:518: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (50, 50) which is of type tuple.
#   warnings.warn(message)
# /tmp/ipykernel_1176/229894683.py:25: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform("mlp_alpha", 1e-5, 1e-1)
# [I 2025-07-28 18:20:07,929] Trial 49 finished with value: 0.9375 and parameters: {'classifier': 'MLP', 'mlp_hidden_layer_sizes': (50, 50), 'mlp_alpha': 0.026584908122212706}. Best is trial 30 with value: 0.94375.

# %%
def get_best_model(params):
    name = params['classifier']
    if name == "LogisticRegression":
        return LogisticRegression(C=params['lr_C'], max_iter=1000)
    elif name == "KNN":
        return KNeighborsClassifier(n_neighbors=params['knn_n_neighbors'])
    elif name == "DecisionTree":
        return DecisionTreeClassifier(max_depth=params['dt_max_depth'])
    elif name == "RandomForest":
        return RandomForestClassifier(n_estimators=params['rf_n_estimators'], max_depth=params['rf_max_depth'])
    elif name == "MLP":
        return MLPClassifier(hidden_layer_sizes=params['mlp_hidden_layer_sizes'], alpha=params['mlp_alpha'], max_iter=1000)
    elif name == "SVC":
        return SVC(C=params['svc_C'], gamma=params['svc_gamma'])

# %%
best_model = get_best_model(study.best_params)
best_model.fit(X_train, y_train)
final_y_pred = best_model.predict(X_test)
print("Acurácia final com melhor modelo:", accuracy_score(y_test, final_y_pred))
print("Precisão final com melhor modelo:", precision_score(y_test, final_y_pred))
print("Recall final com melhor modelo:", recall_score(y_test, final_y_pred))
print("F1 final com melhor modelo:", f1_score(y_test, final_y_pred))
print(f'{best_model}')
# Out:
# Acurácia final com melhor modelo: 0.940625
# Precisão final com melhor modelo: 0.9675324675324676
# Recall final com melhor modelo: 0.9141104294478528
# F1 final com melhor modelo: 0.9400630914826499
# MLPClassifier(alpha=0.00011741869923165701, hidden_layer_sizes=(50, 50),
#               max_iter=1000)

# %%
best_model
# Out:
# MLPClassifier(alpha=0.00011741869923165701, hidden_layer_sizes=(50, 50),
#               max_iter=1000)

# %%
import cv2
from visao.ImageLoader import ImageLoader
from visao.ImageVectorizer import ImageVectorizer

loader = ImageLoader()
vec = ImageVectorizer()

kali = loader.load('../real/suica.png')
# kali = cv2.resize(kali, (512, 512))
kalivec = vec(kali)
print(best_model.predict(scaler.transform(np.array([kalivec]))))
# Out:
# [1]
# /home/diego/miniconda3/envs/visao/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
y_good = final_y_pred[np.where(X_test_original['class'].values == 'good')]
y_low_contrast = final_y_pred[np.where(X_test_original['class'].values == 'low_contrast')]
y_blurry = final_y_pred[np.where(X_test_original['class'].values == 'blurry')]
y_noisy = final_y_pred[np.where(X_test_original['class'].values == 'noisy')]

print(f'Good: Acc: {accuracy_score(y_good, np.ones(y_good.shape[0]))}')
print(f'Low contrast: Acc: {accuracy_score(y_low_contrast, np.zeros(y_low_contrast.shape[0]))}')
print(f'Blurry: Acc: {accuracy_score(y_blurry, np.zeros(y_blurry.shape[0]))}')
print(f'Noisy: Acc: {accuracy_score(y_noisy, np.zeros(y_noisy.shape[0]))}')
# Out:
# Good: Acc: 0.9141104294478528
# Low contrast: Acc: 0.9583333333333334
# Blurry: Acc: 0.9622641509433962
# Noisy: Acc: 0.9821428571428571

# %%
import pickle

with open('tabular_model.pkl', 'wb') as f:
    pickle.dump(best_model, f)


with open('scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)
